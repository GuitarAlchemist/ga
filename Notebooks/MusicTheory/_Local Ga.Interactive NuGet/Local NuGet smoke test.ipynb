// %%
#!csharp
#i "nuget:C:\Users\spare\source\repos\ga\nuget"
#r "nuget:GuitarAlchemist.GA.Interactive.LocalNuGet,*-*"

// %%
#!csharp
using GA.Domain.Core.Theory.Tonal;
using GA.Domain.Core.Primitives.Notes;

Note.Chromatic.C.Display();

// %%
#!csharp
Key.Major.MajorItems.DisplayTable();

// %%
#!csharp
Key.Minor.MinorItems.DisplayTable();

// %%
#!csharp
using GA.Domain.Core.Instruments;
using GA.Data.EntityFramework.Data.Instruments;

Tuning.Default.Display();
Tuning.Ukulele.Display();
Tuning.Bass.Display();

// %%
#!csharp
new[] {
    new { Name = "Guitar", Tuning = Tuning.Default },
    new { Name = "Ukulele", Tuning = Tuning.Ukulele },
    new { Name = "Bass", Tuning = Tuning.Bass }
}.DisplayTable();

// %%
#!csharp
InstrumentsRepository.Instance.InstrumentByName.DisplayTable();
