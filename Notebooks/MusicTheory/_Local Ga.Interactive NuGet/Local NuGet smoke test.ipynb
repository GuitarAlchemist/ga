// %%
#i "nuget:C:\Users\spare\source\repos\ga\nuget"
#r "nuget:GuitarAlchemist.GA.Interactive.LocalNuGet,*-*"
// Out:
// <div><div><strong>Restore sources</strong><ul><li><span>C:\Users\spare\source\repos\ga\nuget</span></li></ul></div><div></div><div><strong>Installed Packages</strong><ul><li><span>GuitarAlchemist.GA.Interactive.LocalNuGet, 2024.3.31.1552</span></li></ul></div></div>
// Loading extensions from `C:\Users\spare\.nuget\packages\guitaralchemist.ga.interactive.localnuget\2024.3.31.1552\interactive-extensions\dotnet\GA.InteractiveExtension.dll`
// <pre style="font-family: monospace">   ____       _ _                  _    _      _                    _     _
//   / ___|_   _(_) |_ __ _ _ __     / \  | | ___| |__   ___ _ __ ___ (_)___| |_
//  | |  _| | | | | __/ _` | '__|   / _ \ | |/ __| '_ \ / _ \ '_ ` _ \| / __| __|
//  | |_| | |_| | | || (_| | |     / ___ \| | (__| | | |  __/ | | | | | \__ \ |_
//   \____|\__,_|_|\__\__,_|_|    /_/   \_\_|\___|_| |_|\___|_| |_| |_|_|___/\__|
//
// </pre>
// <details>
//     <summary>
// ...

// %%
using GA.Business.Core;

Assets.Names.DisplayTable();
// Out:
// <table><thead><tr><td><span>value</span></td></tr></thead><tbody><tr><td>HarmonicMinorScaleDegrees</td></tr><tr><td>AccidentedNotes</td></tr><tr><td>NaturalNotes</td></tr><tr><td>SharpNotes</td></tr><tr><td>MelodicMinorScaleDegrees</td></tr><tr><td>FlatNotes</td></tr><tr><td>Cardinalities</td></tr><tr><td>IntervalClasses</td></tr><tr><td>PitchClasses</td></tr><tr><td>KeySignatures</td></tr><tr><td>NaturalMinorScaleDegrees</td></tr><tr><td>RelativeFrets</td></tr><tr><td>CompoundIntervalSizes</td></tr><tr><td>Fingers</td></tr><tr><td>Keys</td></tr><tr><td>Frets</td></tr><tr><td>IntervalSizes</td></tr><tr><td>ModalFamilies</td></tr><tr><td>FingerCounts</td></tr><tr><td>Scales</td></tr><tr><td colspan="1"><i>(2 more)</i></td></tr></tbody></table><style>
// .dni-code-hint {
//     font-style: italic;
//     overflow: hidden;
//     white-space: nowrap;
// }
// .dni-treeview {
//     white-space: nowrap;
// }
// .dni-treeview td {
//     vertical-align: top;
//     text-align: start;
// ...

// %%
using GA.Business.Core.Tonal;

Key.Major.MajorItems.DisplayTable();
// Out:
// <table><thead><tr><td><span>KeyMode</span></td><td><span>Root</span></td><td><span>KeySignature</span></td><td><span>AccidentalKind</span></td></tr></thead><tbody><tr><td><span>Major</span></td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>Cb</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>FlatAccidental</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>b</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>Value</td><td><div class="dni-plaintext"><pre>-1</pre></div></td></tr></tbody></table></div></details></td></tr><tr><td>PitchClass</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>E</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>Value</td><td><div class="dni-plaintext"><pre>11</pre></div></td></tr></tbody></table></div></details></td></tr><tr><td>AccidentalKind</td><td><span>Flat</span></td></tr><tr><td>Accidental<
// ...

// %%
Key.Minor.MinorItems.DisplayTable();
// Out:
// <table><thead><tr><td><span>KeyMode</span></td><td><span>Root</span></td><td><span>KeySignature</span></td><td><span>AccidentalKind</span></td></tr></thead><tbody><tr><td><span>Minor</span></td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>Ab</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>FlatAccidental</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>b</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>Value</td><td><div class="dni-plaintext"><pre>-1</pre></div></td></tr></tbody></table></div></details></td></tr><tr><td>PitchClass</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>8</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>Value</td><td><div class="dni-plaintext"><pre>8</pre></div></td></tr></tbody></table></div></details></td></tr><tr><td>AccidentalKind</td><td><span>Flat</span></td></tr><tr><td>Accidental</
// ...

// %%
using GA.Business.Config;

Instruments.Instrument.Guitar.Display();
Instruments.Instrument.Banjo.Display();
Instruments.Instrument.Ukulele.Display();
// Out:
// <details open="open" class="dni-treeview"><summary><span class="dni-code-hint"><code>GA.Business.Config.Instruments+Config+Guitar_Type</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>DisplayName</td><td><div class="dni-plaintext"><pre>Guitar</pre></div></td></tr><tr><td>Standard</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>GA.Business.Config.Instruments+Config+Guitar_Type+Standard_Type</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>DisplayName</td><td><div class="dni-plaintext"><pre>Standard</pre></div></td></tr><tr><td>Tuning</td><td><div class="dni-plaintext"><pre>E2 A2 D3 G3 B3 E4</pre></div></td></tr></tbody></table></div></details></td></tr><tr><td>DADGAD</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>GA.Business.Config.Instruments+Config+Guitar_Type+DADGAD_Type</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>DisplayName</td><td><d
// ...

// %%
using GA.Business.Core;

Assets.AssetByName.DisplayTable();
// Out:
// <table><thead><tr><td><span>Key</span></td><td><span>Value</span></td></tr></thead><tbody><tr><td>HarmonicMinorScaleDegrees</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>Asset { Name = HarmonicMinorScaleDegrees, Items = System.Collections.Immutable.ImmutableList`1[System.Object], TypedItems = 1 2 3 4 5 6 7 }</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>TypedItems</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>[ 1, 2, 3, 4, 5, 6, 7 ]</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>Count</td><td><div class="dni-plaintext"><pre>7</pre></div></td></tr><tr><td><i>(values)</i></td><td><table><thead><tr><th><i>index</i></th><th>value</th></tr></thead><tbody><tr><td>0</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>1</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>Value</td><td><div class="dni-plaintext"><pre>1
// ...

// %%
using GA.Business.Core.Instruments;

InstrumentFinder.Instance["Guitar"].Display();
InstrumentFinder.Instance["Ukulele"].Display();
// Out:
// <details open="open" class="dni-treeview"><summary><span class="dni-code-hint"><code>Guitar (15 tunings)</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>Name</td><td><div class="dni-plaintext"><pre>Guitar</pre></div></td></tr><tr><td>Tunings</td><td><table><thead><tr><th><i>key</i></th><th>value</th></tr></thead><tbody><tr><td><div class="dni-plaintext"><pre>Baroque 2</pre></div></td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>Baroque 2 - A3 A3 D4 D3 G3 G3 B3 B3 E4 E4</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>Name</td><td><div class="dni-plaintext"><pre>Baroque 2</pre></div></td></tr><tr><td>Tuning</td><td><div class="dni-plaintext"><pre>A3 A3 D4 D3 G3 G3 B3 B3 E4 E4</pre></div></td></tr><tr><td>TuningInstance</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>GA.Business.Config.Instruments+Config+Guitar_Type+Baroque2_Type</code></span></summary><div><table><thead
// ...

// %%
InstrumentFinder.Instance.InstrumentByName.DisplayTable();
// Out:
// <table><thead><tr><td><span>Key</span></td><td><span>Value</span></td></tr></thead><tbody><tr><td>Angelique ( Theorbo)</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>Angelique ( Theorbo) (1 tunings)</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>Name</td><td><div class="dni-plaintext"><pre>Angelique ( Theorbo)</pre></div></td></tr><tr><td>Tunings</td><td><table><thead><tr><th><i>key</i></th><th>value</th></tr></thead><tbody><tr><td><div class="dni-plaintext"><pre>Standard</pre></div></td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>Standard - D2 E2 F2 G2 A2 B2 C3 D3 E3 F3 G3 A3 B3 C4 D4 E4</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>Name</td><td><div class="dni-plaintext"><pre>Standard</pre></div></td></tr><tr><td>Tuning</td><td><div class="dni-plaintext"><pre>D2 E2 F2 G2 A2 B2 C3 D3 E3 F3 G3 A3 B3 C4 D4 E4</pre></div></td></tr><tr><td>TuningInstance</td><td><de
// ...
