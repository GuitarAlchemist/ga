// %%
#!csharp
#i "nuget:C:\Users\spare\source\repos\ga\nuget"
#r "nuget:FSharp.Configuration,2.0.0"
#r "nuget:GuitarAlchemist.GA.Interactive.LocalNuGet,*-*"

using GA.Domain.Core.Instruments;

Tuning.Default.Display();

// %%
#!csharp
// Guitar
var guitar = Tuning.Default;
guitar.Display();

// %%
#!csharp
// Ukulele
var ukulele = Tuning.Ukulele;
ukulele.Display();

// %%
#!csharp
// All Tunings
new[] {
    new { Name = "Guitar", Tuning = Tuning.Default },
    new { Name = "Ukulele", Tuning = Tuning.Ukulele },
    new { Name = "Bass", Tuning = Tuning.Bass },
    new { Name = "7-String Guitar", Tuning = Tuning.Guitar7String }
}.DisplayTable();
