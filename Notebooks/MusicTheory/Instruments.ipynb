// %%
#r "nuget:FSharp.Configuration,2.0.0"
#r "nuget:GuitarAlchemist.GA.Interactive,*-*"

using GA.Business.Core.Instruments;

InstrumentFinder.Instance.InstrumentByName.DisplayTable();
// Out:
// <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>FSharp.Configuration, 2.0.0</span></li><li><span>GuitarAlchemist.GA.Interactive, 1.0.1-beta5</span></li></ul></div></div>
// Loading extensions from `C:\Users\spare\.nuget\packages\guitaralchemist.ga.interactive\1.0.1-beta5\interactive-extensions\dotnet\GA.InteractiveExtension.dll`
// <pre style="font-family: monospace">   ____       _ _                  _    _      _                    _     _
//   / ___|_   _(_) |_ __ _ _ __     / \  | | ___| |__   ___ _ __ ___ (_)___| |_
//  | |  _| | | | | __/ _` | '__|   / _ \ | |/ __| '_ \ / _ \ '_ ` _ \| / __| __|
//  | |_| | |_| | | || (_| | |     / ___ \| | (__| | | |  __/ | | | | | \__ \ |_
//   \____|\__,_|_|\__\__,_|_|    /_/   \_\_|\___|_| |_|\___|_| |_| |_|_|___/\__|
//
// </pre>
// <details>
//     <summary>
//         Renders Guitar Alchemist objects in dotnet-interactive notebooks
//         (81 formatters registered)
//     </summary>
// ...

// %%
// Guitar
var guitar = InstrumentFinder.Instance["Guitar"];
guitar.Display();
// Out:
// <details open="open" class="dni-treeview"><summary><span class="dni-code-hint"><code>Guitar (15 tunings)</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>Name</td><td><div class="dni-plaintext"><pre>Guitar</pre></div></td></tr><tr><td>Tunings</td><td><table><thead><tr><th><i>key</i></th><th>value</th></tr></thead><tbody><tr><td><div class="dni-plaintext"><pre>Open E Major V 2</pre></div></td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>Open E Major V 2 - E2 B2 E3 G3 B3 E4</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>Name</td><td><div class="dni-plaintext"><pre>Open E Major V 2</pre></div></td></tr><tr><td>Tuning</td><td><div class="dni-plaintext"><pre>E2 B2 E3 G3 B3 E4</pre></div></td></tr><tr><td>TuningInstance</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>GA.Business.Config.Instruments+Config+Guitar_Type+OpenEMajorV2_Type</code></span></summary><div><table><thea
// ...

// %%
// Instruments by first letter
using System.Linq;

InstrumentFinder.Instance.InstrumentNames.GroupBy(a => a.First()).DisplayTable()
// Out:
// <table><thead><tr><td><span>value</span></td></tr></thead><tbody><tr><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>[ Angelique ( Theorbo), Archlute ]</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>Key</td><td><div class="dni-plaintext"><pre>A</pre></div></td></tr><tr><td><i>(values)</i></td><td><div class="dni-plaintext"><pre>[ Angelique ( Theorbo), Archlute ]</pre></div></td></tr></tbody></table></div></details></td></tr><tr><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>[ Baglama, Bajo, Balalaika, Bandola, Bandolim, Bandolin, Bandora, Bandurria, Banjo, Banjolin, Banjourine, Baritone Guitar, Baroque Lute, Bass Guitar, Bordonua, Bouzouki, Braguinha ]</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>Key</td><td><div class="dni-plaintext"><pre>B</pre></div></td></tr><tr><td><i>(values)</i></td><td><div class="dni-plaintext"><pre>[ Baglama, Bajo, Balalaika, Bandola, Bandolim
// ...
