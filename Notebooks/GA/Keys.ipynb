// %%
#r "nuget:FSharp.Configuration,2.0.0"
#r "nuget:GuitarAlchemist.GA.Interactive,*-*"

using GA.Business.Core.Tonal;
// Out:
// <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>FSharp.Configuration, 2.0.0</span></li><li><span>GuitarAlchemist.GA.Interactive, 1.0.1-beta4</span></li></ul></div></div>
// Loading extensions from `C:\Users\spare\.nuget\packages\guitaralchemist.ga.interactive\1.0.1-beta4\interactive-extensions\dotnet\GA.InteractiveExtension.dll`
// <pre style="font-family: monospace">   ____       _ _                  _    _      _                    _     _
//   / ___|_   _(_) |_ __ _ _ __     / \  | | ___| |__   ___ _ __ ___ (_)___| |_
//  | |  _| | | | | __/ _` | '__|   / _ \ | |/ __| '_ \ / _ \ '_ ` _ \| / __| __|
//  | |_| | |_| | | || (_| | |     / ___ \| | (__| | | |  __/ | | | | | \__ \ |_
//   \____|\__,_|_|\__\__,_|_|    /_/   \_\_|\___|_| |_|\___|_| |_| |_|_|___/\__|
//
// </pre>
// <details>
//     <summary>
//         Renders Guitar Alchemist objects in dotnet-interactive notebooks
//         (79 formatters registered)
//     </summary>
// ...

// %%
// Key signatures
KeySignature.Items.DisplayTable();
// Out:
// <table><thead><tr><td><span>value</span></td></tr></thead><tbody><tr><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>[ Bb, Eb, Ab, Db, Gb, Cb, Fb ]</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>Count</td><td><div class="dni-plaintext"><pre>7</pre></div></td></tr><tr><td>Value</td><td><div class="dni-plaintext"><pre>-7</pre></div></td></tr><tr><td>AccidentedNotes</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>[ Bb, Eb, Ab, Db, Gb, Cb, Fb ]</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>Count</td><td><div class="dni-plaintext"><pre>7</pre></div></td></tr><tr><td>PrintOut</td><td><div class="dni-plaintext"><pre>Bb Eb Ab Db Gb Cb Fb</pre></div></td></tr><tr><td><i>(values)</i></td><td><table><thead><tr><th><i>index</i></th><th>value</th></tr></thead><tbody><tr><td>0</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>Bb</code></span></summary
// ...

// %%
// Major keys
Key.Major.MajorItems.DisplayTable();
// Out:
// <table><thead><tr><td><span>KeyMode</span></td><td><span>Root</span></td><td><span>KeySignature</span></td><td><span>AccidentalKind</span></td></tr></thead><tbody><tr><td><span>Minor</span></td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>Ab</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>FlatAccidental</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>b</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>Value</td><td><div class="dni-plaintext"><pre>-1</pre></div></td></tr></tbody></table></div></details></td></tr><tr><td>PitchClass</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>8</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>Value</td><td><div class="dni-plaintext"><pre>8</pre></div></td></tr></tbody></table></div></details></td></tr><tr><td>AccidentalKind</td><td><span>Flat</span></td></tr><tr><td>Accidental</
// ...

// %%
// Minor keys
Key.Minor.MinorItems.DisplayTable();
// Out:
// <table><thead><tr><td><span>KeyMode</span></td><td><span>Root</span></td><td><span>KeySignature</span></td><td><span>AccidentalKind</span></td></tr></thead><tbody><tr><td><span>Minor</span></td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>Ab</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>FlatAccidental</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>b</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>Value</td><td><div class="dni-plaintext"><pre>-1</pre></div></td></tr></tbody></table></div></details></td></tr><tr><td>PitchClass</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>8</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>Value</td><td><div class="dni-plaintext"><pre>8</pre></div></td></tr></tbody></table></div></details></td></tr><tr><td>AccidentalKind</td><td><span>Flat</span></td></tr><tr><td>Accidental</
// ...
