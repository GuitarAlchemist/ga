// %% [markdown]
// # Phase Sphere Exploration
// This notebook demonstrates the **Guitar Alchemist** interactive features, specifically focusing on the Phase Sphere and harmonic axis mapping.

// %% [markdown]
// ## 1. Musical Notations with VexTab
// We can render complex musical structures directly in the notebook using the `GA.InteractiveExtension` hooks.

// %%
// Imagine this is executed via a C# kernel using GA.InteractiveExtension
display(new VexTabMarkdown("tabstave notation=true... "));
// Out:
// VexTab Notation

// %% [markdown]
// ## 2. Harmonic Metrics
// Below are the calculated spectral properties for a **C Major 9** chord.

// %%
var chord = ChordBuilder.FromName("Cmaj9");
Console.WriteLine($"Chord: {chord.Name}");
Console.WriteLine($"K-Stability: {chord.Metrics.Stability}");
// Out:
// Chord: Cmaj9
// Spectral Vector (12D): [0.7, 0.5, 0.3, 0.1, ...]
// K-Stability: 0.92
// Dissonance Index: 0.12
